# %% [markdown]
# <a href="https://colab.research.google.com/github/asennakesavan/kesavan_code/blob/master/Stats4_cov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
insurance_data = pd.read_csv(r"https://raw.githubusercontent.com/Laxminarayen/InceptezGenAI-Batch26/refs/heads/main/14.%20Data%20Preprocessing/Data/insurance.csv")

# %%
insurance_data.head() #Based on the personal information given
#predict Insurance Premium expense - X1, X2, X3, X4, X5, X6 - Expense: Y
#All of these X variables independent Variables?
#Y - Prediction variable or Y to be dependent on the variables I use to predict.
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
insurance_data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
insurance_data['sex'] = insurance_data['sex'].map({'male':1,'female':0})
insurance_data['smoker'] = insurance_data['smoker'].map({'yes':1,'no':0})
insurance_data['region'] = insurance_data['region'].map({'southwest':1,'southeast':2,'northwest':3})

# %%
import seaborn as sns
import matplotlib.pyplot as plt
insurance_data.cov()
# Out:
#                    age         sex           bmi    children        smoker  \
# age         197.401387   -0.146559      9.368560    0.719303 -1.419035e-01
# sex          -0.146559    0.250160      0.141467    0.010348  1.538259e-02
# bmi           9.368560    0.141467     37.190265    0.092958  9.768876e-03
# children      0.719303    0.010348      0.092958    1.453213  3.734126e-03
# smoker       -0.141903    0.015383      0.009769    0.003734  1.629689e-01
# region       -0.082922   -0.001974     -0.447483    0.001974  7.233437e-18
# expenses  50874.802133  347.014516  14665.149703  992.674243  3.848667e+03
#
#                 region      expenses
# age      -8.292201e-02  5.087480e+04
# sex      -1.974334e-03  3.470145e+02
# bmi      -4.474827e-01  1.466515e+04
# children  1.974334e-03  9.926742e+02
# smoker    7.233437e-18  3.848667e+03
# region    6.416584e-01  2.266250e+01
# expenses  2.266250e+01  1.466524e+08

# %%
print(insurance_data.corr())
# Out:
#                age       sex       bmi  children        smoker        region  \
# age       1.000000 -0.020856  0.109341  0.042469 -2.501875e-02 -7.367464e-03
# sex      -0.020856  1.000000  0.046380  0.017163  7.618482e-02 -4.927365e-03
# bmi       0.109341  0.046380  1.000000  0.012645  3.968054e-03 -9.194905e-02
# children  0.042469  0.017163  0.012645  1.000000  7.673120e-03  2.040754e-03
# smoker   -0.025019  0.076185  0.003968  0.007673  1.000000e+00  2.239208e-17
# region   -0.007367 -0.004927 -0.091949  0.002041  2.239208e-17  1.000000e+00
# expenses  0.299008  0.057292  0.198576  0.067998  7.872514e-01  2.286085e-03
#
#           expenses
# age       0.299008
# sex       0.057292
# bmi       0.198576
# children  0.067998
# smoker    0.787251
# region    0.002286
# expenses  1.000000

# %%
sns.heatmap(insurance_data.corr(),annot=True)
# Out:
# <Axes: >
