# %% [markdown]
# <a href="https://colab.research.google.com/github/asennakesavan/kesavan_code/blob/master/Python_Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def myfunction(nums):
  print(nums)
  print(type(nums))
  return sum(nums)

# %%
myfunction(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3163/2816920324.py in <cell line: 0>()
# ----> 1 myfunction(1,2)
#
# TypeError: myfunction() takes 1 positional argument but 2 were given

# %%
def myfunction(nums,userdict):
  print(nums)
  print(type(nums))
  print(userdict)
  print(type(userdict))

# %%
myfunction(1,{'Batch':26,'Course':'GenAI'})
# Out:
# 1
# <class 'int'>
# {'Batch': 26, 'Course': 'GenAI'}
# <class 'dict'>

# %%
class Car:
  def __init__(sefl,brand,color,model,transmission):
    sefl.brand = brand
    sefl.color = color
    sefl.model = model
    sefl.transmission = transmission

  def honk(sefl, times=1):
    for _ in range(times):
      print(f"{sefl.brand} {sefl.color} {sefl.model} honks!")

  def mode(sefl):
    print(f"{sefl.brand} {sefl.model} is {sefl.transmission}")

# %% [markdown]
# # New Section

# %%
  cars1 = Car('Hyundai','Red','i20','AT')

# %%
cars1.honk()
cars1.mode()
# Out:
# Hyundai Red i20 honks!
# Hyundai i20 is AT

# %%
  cars2 = Car('Skoda','Black','kia')

# %%
cars2.honk()
# Out:
# Skoda Black kia

# %%
from car import Car

# %%
cars1 = Car('Hyundai','Red','i20','AT')

# %%
cars1.mode()
# Out:
# Hyundai i20 is AT

# %%
class Car:
  def honk(sefl, times=1):
    for _ in range(times):
      print(f"{sefl.brand} {sefl.color} {sefl.model} honks!")

  def mode(sefl):
    print(f"{sefl.brand} {sefl.model} is {sefl.transmission}")

# %%
cars1 =Car()
Car.brand = 'Hyundai'
Car.color = 'Red'
Car.model = 'i20'
Car.transmission = 'AT'
cars1.honk()
cars1.mode()
# Out:
# Hyundai Red i20 honks!
# Hyundai i20 is AT

# %%
class Githubtool:
  def __init__(self,api_key):
    self.api_key = api_key

  def search(self,query,**filters):
    if filters:
      print("Applying Filters")
      for key,value in filters.items():
        print(f"{key} : {value}")
    else:
      print("No Filters Applied")
   # print(f"{self.query} {self.filters}")

# %%
mytool = Githubtool("ghp_12345")
mytool.search("ML",language="python",sort="Updated")
# Out:
# Applying Filters
# language : python
# sort : Updated

# %%
y = 10
def add():
  global y
  x=7
  print(f"x value inside function {x}")
add()
print(f"x value outside function {y}")
# Out:
# x value inside function 7
# x value outside function 10

# %%
add()
# Out:
# x value inside function 10

# %%
x =10
def outer():
  x=16
  print('Outer function value is: ', x)
  def inner():
    x=20
    print('Inner function value is: ', x)
  inner()
outer()
# Out:
# Outer function value is:  16
# Inner function value is:  20

# %%
outer()
# Out:
# Outer function value is:  16
# Inner function value is:  16

# %%
sum = 100
print(sum)
# Out:
# 100

# %%
sum([1,2,3,4])
print(sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3884/326306933.py in <cell line: 0>()
# ----> 1 sum([1,2,3,4])
#       2 print(sum)
#
# TypeError: 'int' object is not callable
